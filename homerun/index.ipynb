# %%
import matplotlib.pyplot as plt

# %%
# x: 打球速度(km/h)
# y: 打球角度(°)

x1 = [181.69, 186.84, 184.59, 172.52, 179.92, 178.15, 177.19, 172.68, 169.95, 182.02, 177.67, 181.21, 172.68, 187.49, 184.27, 181.05, 168.18, 178.80, 180.89, 176.38, 188.61, 173.00, 186.84, 166.57, 173.16, 183.95, 175.42, 178.48, 186.36, 179.76, 181.05, 188.29, 180.09, 170.43, 155.46, 163.67, 173.16, 177.51, 156.11, 172.36, 174.29, 172.52, 175.26, 174.13, 185.40, 171.07]
y1 = [20, 26, 22, 31, 38, 45, 31, 24, 25, 22, 26, 25, 25, 31, 25, 31, 30, 28, 18, 23, 25, 38, 27, 23, 25, 18, 26, 30, 25, 31, 21, 24, 31, 27, 36, 33, 33, 34, 34, 27, 33, 38, 29, 30, 21, 29]

x2 = [165.28, 179.76, 178.15, 183.30, 182.18, 170.59, 165.92, 183.95, 155.30, 166.24, 175.74, 180.41, 173.16, 155.78, 185.40, 183.46, 179.60, 161.26, 161.09, 173.65, 173.97, 173.49, 165.28, 172.68, 182.02, 174.45, 184.59, 178.80, 173.33, 179.12, 159.97, 177.51, 184.59, 188.94, 163.03, 183.30, 170.27, 184.11, 172.68, 151.76, 171.07, 177.83, 174.45, 167.21, 169.30, 181.53, 179.12, 172.04]
y2 = [28, 27, 21, 15, 24, 29, 30, 20, 32, 26, 26, 20, 23, 29, 19, 27, 24, 23, 30, 28, 33, 21, 23, 21, 28, 29, 24, 21, 30, 24, 36, 20, 17, 23, 32, 22, 19, 26, 26, 28, 23, 20, 26, 25, 34, 24, 21, 23]

x3 = [182.50, 173.97, 165.12, 172.04, 173.16, 174.45, 169.62, 179.60, 169.95, 160.61, 170.75, 161.42, 167.85, 178.96, 163.99, 161.26, 169.14, 167.69, 176.71, 160.77, 164.47, 159.65, 166.41, 175.26, 175.58, 177.19, 177.83, 170.27, 162.38, 167.69, 171.56, 167.53, 166.57, 161.42, 170.11, 173.16, 181.21, 157.39, 161.26, 164.15, 156.11, 183.79, 175.26, 177.51, 178.48, 177.19, 168.18, 173.00]
y3 = [24, 31, 32, 36, 31, 36, 34, 29, 24, 37, 39, 26, 31, 23, 28, 26, 28, 24, 27, 38, 33, 36, 42, 33, 38, 34, 27, 30, 30, 29, 40, 41, 25, 38, 42, 28, 22, 32, 28, 38, 35, 32, 31, 25, 30, 28, 25, 29]

# %%
fig,ax = plt.subplots()

ax.scatter(x1, y1, c='b')
ax.set_xlim(150, 190)
ax.set_ylim(13, 47)
fig.savefig('ohtani.png',transparent=True)

# %%
fig,ax = plt.subplots()

ax.scatter(x2, y2, c='r')
ax.set_xlim(150, 190)
ax.set_ylim(13, 47)
fig.savefig('guerrero.png',transparent=True)

# %%
fig,ax = plt.subplots()

ax.scatter(x3, y3, c='g')
ax.set_xlim(150, 190)
ax.set_ylim(13, 47)
fig.savefig('perez.png',transparent=True)
